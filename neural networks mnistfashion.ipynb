# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
data = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = data.load_data()

# %%
class_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle Boot']
train_images = train_images/255.0
test_images = test_images/255.0

model = keras.Sequential([
    keras.layers.Flatten(input_shape = (28,28)),
    keras.layers.Dense(128,activation = "relu"),
    keras.layers.Dense(10,activation = "softmax")
])
model.compile(optimizer = "adam",loss = "sparse_categorical_crossentropy",metrics = ["accuracy"])
model.fit(train_images,train_labels,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4938 - accuracy: 0.8275
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3778 - accuracy: 0.8638
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3378 - accuracy: 0.8765
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3153 - accuracy: 0.8838
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2966 - accuracy: 0.8910

# %%
#test_loss,test_acc = model.evaluate(test_images,test_labels)
#print("Tested acc: ",test_acc)
#accuracy on train images, and loss whuch needs to be minimised
prediction = model.predict(test_images)
#print(prediction)
#gives prediction of 10 classes for all test images
#print(prediction[0])
#gives prediction of 0th image i.e. all predictions in a list consisting of 10 classes
#print(np.argmax(prediction[0]))
#gives index of max value in the list
#print(class_names[np.argmax(prediction[523])])
#gives the class name

# %%
for i in range(10,15):
    plt.grid(False)
    plt.imshow(test_images[i],cmap = plt.cm.binary)
    plt.xlabel("Actual: " + class_names[test_labels[i]])
    plt.title("Prediction" + class_names[np.argmax(prediction[i])])
    plt.show()
